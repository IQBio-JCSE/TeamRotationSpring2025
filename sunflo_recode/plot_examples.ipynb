# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ## No terpenoid gene expression, 2 different climate files

# %%
no_terp_output = sorted(glob.glob("/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/nopest*.csv"))
all_no_terp_dfs = dict()
for f in no_terp_output:
    name = f.split("/")[-1].split(".")[0]
    df = pd.read_csv(f, index_col=0)
    all_no_terp_dfs[name] = df

# %%
all_no_terp_dfs["out_2014_noterp"].columns
# Out:
# Index(['TemperatureAirMin', 'TemperatureAirMax', 'TemperatureAirMean',
#        'Radiation', 'PET', 'Rainfall', 'ThermalTime', 'WaterStress',
#        'WaterStressConductance', 'WaterStressRUE',
#        'WaterSupplyDemandRatio....WaterDemand.WaterAvailable',
#        'ThermalStressRUE....ThermalStressRUE',
#        'NitrogenAbsorbed....NitrogenAbsorbed', 'NitrogenNutritionIndex....NNI',
#        'NitrogenStressRUE....NitrogenStressRUE', 'LAI', 'RIE', 'RUE',
#        'CropBiomass', 'CropYield', 'TerpeneStressRUE',
#        'pest_resistance_genetic', 'WaterAvailable'],
#       dtype='object')

# %%
all_no_terp_dfs.keys()
# Out:
# dict_keys(['out_2003_noterp', 'out_2006_noterp', 'out_2014_noterp'])

# %%
plt.figure()

for name,df in all_no_terp_dfs.items():
    plt.plot(df["CropBiomass"], label=name.split("_")[3], alpha=0.8, linewidth=2.5)
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
plt.legend(title="Year",loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
plt.figure()

for name,df in all_no_terp_dfs.items():
    plt.plot(df["ThermalTime"],df["CropBiomass"], label=name.split("_")[1], alpha=0.8, linewidth=2.5)
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
plt.legend(title="Year",loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Thermal Time (ºC * day)",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %% [raw]
# plt.figure()
# plt.plot(all_no_terp_dfs["out_2014_noterp"]["WaterSupplyDemandRatio....WaterDemand.WaterAvailable"], alpha=0.8)
# plt.legend()
# plt.xlabel("Day")
#
# # plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# # plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
all_no_terp_dfs["out_2003_noterp"]
# Out:
#      TemperatureAirMin  TemperatureAirMax  TemperatureAirMean  Radiation  \
# 1                  9.7               18.8               14.25      12.69
# 2                  8.2               11.6                9.90       6.93
# 3                  4.2               10.7                7.45      13.40
# 4                  1.7               13.2                7.45      23.54
# 5                 -0.7               16.8                8.05      24.91
# ..                 ...                ...                 ...        ...
# 146               19.9               33.4               26.65      18.33
# 147               17.4               31.3               24.35      22.63
# 148               19.4               31.1               25.25      21.29
# 149               17.6               36.1               26.85      23.67
# 150               19.9               30.0               24.95      11.44
#
#       PET  Rainfall  ThermalTime  WaterStress  WaterStressConductance  \
# ...

# %%
all_output = glob.glob("/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress*.csv")
#df = pd.read_csv(infile, index_col=0)

# %%
all_output
# Out:
# ['/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_1.00_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_2.50_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_3.00_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_0.50_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_0.00_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_1.50_out.csv',
#  '/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/terp_stress_2.00_out.csv']

# %%
all_dfs = list()
for f in sorted(all_output):
    df = pd.read_csv(f, index_col=0)
    all_dfs.append(df)

# %%
df
# Out:
#      TemperatureAirMin  TemperatureAirMax  TemperatureAirMean  Radiation  PET  \
# 1                 12.0               18.2               15.10      19.44  4.3
# 2                 12.4               16.1               14.25      10.05  3.6
# 3                 10.9               14.4               12.65       2.09  0.8
# 4                  9.5               16.1               12.80       7.61  1.9
# 5                  4.1               19.0               11.55      19.72  2.6
# ..                 ...                ...                 ...        ...  ...
# 146               12.9               24.7               18.80      23.38  4.1
# 147               14.4               30.0               22.20      21.75  4.5
# 148               16.5               25.8               21.15      18.64  3.8
# 149               18.4               26.5               22.45      15.71  3.5
# 150               14.2               30.5               22.35      22.96  4.3
#
# ...

# %%
plt.figure()
for df in all_dfs:
    plt.plot(df["CropBiomass"][20:135], label=df["pest_resistance_genetic"].tolist()[0])
plt.legend(title="Terpenoid expresion level")
plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
plt.figure()
plt.plot(all_dfs[0]["CropBiomass"][20:130], label=all_dfs[0]["pest_resistance_genetic"].tolist()[0], linewidth=2.5)
# plt.plot(all_dfs[2]["CropBiomass"][20:130], label=all_dfs[2]["pest_resistance_genetic"].tolist()[0])
plt.plot(all_dfs[-1]["CropBiomass"][20:130], label=all_dfs[-1]["pest_resistance_genetic"].tolist()[0],  linewidth=2.5)
plt.legend(title="Terpenoid expression level",loc="lower right")
plt.gca().spines[["right","top"]].set_visible(False)

# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')
plt.title("Effect of terpenoid expression on crop biomass",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.savefig("sample_terpenoid_expr_effect.svg", dpi=400,  bbox_inches='tight', transparent=True)

# %%
for column in df.columns:
    plt.figure()
    df[column].plot(title=column)
    plt.xlabel("Day")
    plt.ylabel(column)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plt.figure()
plt.scatter(df["ThermalTime"],df["CropBiomass"])
plt.title("Accumulation of crop biomass (g/m^2) with temperature")
plt.xlabel("ThermalTime")
plt.ylabel("Crop Biomass (g/m^2) ")
plt.savefig("test_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
list(df["CropBiomass"] > 0).index(True)
# Out:
# 16

# %%
df.iloc[16]

# %%
df.iloc[15:17] #Intro of the second leaf
# Out:
#     TemperatureAirMin  TemperatureAirMax  TemperatureAirMean  Radiation  PET  \
# 16                4.0               24.6               14.30      25.45  4.2
# 17               10.1               23.8               16.95      25.01  5.0
#
#     Rainfall  ThermalTime  WaterStress  WaterStressConductance  \
# 16       0.0   143.946901     0.041067                0.856393
# 17       0.0   156.291994     0.037725                0.839430
#
#     WaterStressRUE  WaterSupplyDemandRatio....WaterDemand.WaterAvailable  \
# 16        0.181735                                                0.0
# 17        0.167234                                                0.0
#
#     ThermalStressRUE....ThermalStressRUE  \
# 16                              0.625000
# 17                              0.799342
#
#     NitrogenAbsorbed....NitrogenAbsorbed  NitrogenNutritionIndex....NNI  \
# 16                                   0.0                            0.0
# ...

# %%
years = ["14","15","16"]
colors=plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.figure()

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/nopest*{year}*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=2.5, color=colors[i])
    
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.ylim([0,500])
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
years = ["14","15","16"]
# colors=plt.rcParams['axes.prop_cycle'].by_key()['color'][2:]
# plt.figure()

# for i in range(len(years)):
#     year = years[i]
#     output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/nopest*{year}*.csv"))
#     all_out = dict()
#     for f in output:
#         name = f.split("/")[-1].split(".")[0]
#         df = pd.read_csv(f, index_col=0)
#         all_out[name] = df
    
    
#     for name,df in all_out.items():
#         plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=2.5, color=colors[i])
  

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/PEST*{year}*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=2.5, color=colors[i+3])
    
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
plt.ylim([0,500])
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
years = ["14","15","16"]
colors=plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.figure()

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/nopest*{year}*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.scatter(df["pest_resistance_genetic"].tolist()[-1], df["CropBiomass"].tolist()[-1], color=colors[i])

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/PEST*{year}*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.scatter(df["pest_resistance_genetic"].tolist()[-1], df["CropBiomass"].tolist()[-1], color=colors[i+3])
    
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
# plt.ylim([0,500])
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

# %%
years = ["14","15","16"]
colors=plt.rcParams['axes.prop_cycle'].by_key()['color']
# plt.figure()
fig, ax = plt.subplots()

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="blue")

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="orange")
    
for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="green")

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="magenta")
    
        
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="orange", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="magenta", lw=4)]


# lines = ax.plot(data)

ax.legend(custom_lines, ['2014 domesticated', '2014 WT', '1994 domesticated','1994 WT'])
plt.savefig("timediff_domVwt.svg", dpi=400,  bbox_inches='tight', transparent=True)

# %%
import statistics

years = ["14","15","16"]
colors=plt.rcParams['axes.prop_cycle'].by_key()['color']
# plt.figure()
fig, ax = plt.subplots()

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    data = list()
    for name,df in all_out.items():
        data.append(df["CropBiomass"].tolist()[-1])
    
    plt.hist(data, label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="magenta")
    print("WT 94", statistics.mean(data))
    
for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    data = list()
    for name,df in all_out.items():
        data.append(df["CropBiomass"].tolist()[-1])
    

    
    plt.hist(data, label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="blue" )
    print("WT 14", statistics.mean(data))
             
#     for name,df in all_out.items():
#         plt.hist(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.1, linewidth=1, color="blue")

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    data = list()
    for name,df in all_out.items():
        data.append(df["CropBiomass"].tolist()[-1])
    
    plt.hist(data, label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="orange")
    print("dom 14", statistics.mean(data))
#     for name,df in all_out.items():
#         plt.hist(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.1, linewidth=1, color="orange")
    
for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    data = list()
    for name,df in all_out.items():
        data.append(df["CropBiomass"].tolist()[-1])
    
    plt.hist(data, label="Domesticated 20"+year, alpha=0.5, linewidth=1, color = "green")
    print("dom 94",statistics.mean(data))
#     for name,df in all_out.items():
#         plt.hist(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.1, linewidth=1, color="green")


        
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xlabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="orange", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="magenta", lw=4)]


# lines = ax.plot(data)

ax.legend(custom_lines, ['2014 domesticated', '2014 WT', '1994 domesticated','1994 WT'])
# plt.savefig("timediff_domVwt.svg", dpi=400,  bbox_inches='tight', transparent=True)
# Out:
# WT 94 466.093930135383
# WT 94 466.093930135383
# WT 94 466.093930135383
# WT 14 412.9189498965319
# WT 14 412.9189498965319
# WT 14 412.9189498965319
# dom 14 466.389158424524
# dom 14 466.389158424524
# dom 14 466.389158424524
# dom 94 527.5063086295136
# dom 94 527.5063086295136
# dom 94 527.5063086295136

# %%
years = ["14","15","16"]
colors=plt.rcParams['axes.prop_cycle'].by_key()['color']
# plt.figure()
fig, ax = plt.subplots()

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="blue")

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*2014*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="orange")
    
for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/dom*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="green")

for i in range(len(years)):
    year = years[i]
    output = sorted(glob.glob(f"/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/WT*1994*.csv"))
    all_out = dict()
    for f in output:
        name = f.split("/")[-1].split(".")[0]
        df = pd.read_csv(f, index_col=0)
        all_out[name] = df
    
    
    for name,df in all_out.items():
        plt.plot(df["CropBiomass"], label="Domesticated 20"+year, alpha=0.5, linewidth=1, color="magenta")
    
        
    
#     plt.plot(df["Rainfall"], label=name, alpha=0.8)
# plt.legend(loc="lower right")
plt.title("Accumulation of crop biomass over time",fontsize=14)
plt.xlabel("Day",fontsize=14)
plt.ylabel("Crop Biomass (g/m^2) ",fontsize=14)
plt.gca().spines[["right","top"]].set_visible(False)
# plt.savefig("growth_under_different_conditions.svg", dpi=400,  bbox_inches='tight', transparent=True)
# plt.savefig("sample_terpenoid_expr_effect.png", dpi=400,  bbox_inches='tight', transparent=True)
# plt.show()
# plt.savefig("varied_water_stress_biomassVthermaltime.png", dpi=400,  bbox_inches='tight')

from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="orange", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="magenta", lw=4)]


# lines = ax.plot(data)

ax.legend(custom_lines, ['2014 domesticated', '2014 WT', '1994 domesticated','1994 WT'])
# plt.savefig("timediff_domVwt.svg", dpi=400,  bbox_inches='tight', transparent=True)

# %% [markdown]
# Different climate file effect

# %%
no_terp_output = sorted(glob.glob("/Users/jennastanislaw/Boulder/team_rotation/TeamRotationSpring2025/sunflo_recode/examples_for_presentation/years_output/nopest*.csv"))
all_no_terp_dfs = dict()
for f in no_terp_output:
    name = f.split("/")[-1].split(".")[0]
    df = pd.read_csv(f, index_col=0)
    all_no_terp_dfs[name] = df
